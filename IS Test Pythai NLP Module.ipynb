# %% [markdown]
# # PyThaiNLP Module for IS

# %% [markdown]
# # Tokenization
# Sentence and Word Default word tokenizer ("newmm") use maximum matching algorithm.

# %%
import pythainlp

from pythainlp import sent_tokenize, word_tokenize

text = """
ชาหอมอร่อยดี อร่อยมากจ้า ความรวดเร็วในการจัดส่งดีมาก 
แพคสินค้าดี สินค้าคุณภาพสมราคา แม่ค้าน่ารักมาก ให้บริการดีมาก 
คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก
ขนมตุ๊บตั๊บแพคมาดีค่ะ เห็ดหอมสภาพดีค่ะ  
ดอกไม่ใหญ่มากขนาดกลางๆ 
สินค้าสภาพดี สมราคา 
คุ้มค่าไม่ไก่กาค่ะ กลิ่นชาหอมมากกชาหอมมากค่ะ สินค้าดีนะคะ 
เข้ากับสีผิวดีสินค้าคุณภาพดีมาก ผ้าหนามาก ดีมาก ได้รับของไวมากค่ะ ไม่อร่อย  
สั่งอย่างหนึ่งได้อย่างหนึ่ง ไม่คุ้มกับความรู้สึกเมื่อเจอ  
ถุงเท้าแข็งมากใส่ไม่สบายเลย ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย 
การให้บริการจากร้านค้าแย่มาก คุณภาพของสินค้าแย่มาก คุณภาพของสินค้าบางเกิน 
คุณภาพของสินค้าแย่มาก ความคุ้มค่าแย่มาก ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ 
คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ เลยทิ้งทั้งหมดที่ซื้อ เป้าขาด"""
print("sent_tokenize:", sent_tokenize(text))
print("word_tokenize:", word_tokenize(text))
print("word_tokenize, without whitespace:", word_tokenize(text, keep_whitespace=False))
# Out:
# sent_tokenize: ['ชาหอมอร่อยดี', 'อร่อยมากจ้า', 'ความรวดเร็วในการจัดส่งดีมาก', 'แพคสินค้าดี', 'สินค้าคุณภาพสมราคา', 'แม่ค้าน่ารักมาก', 'ให้บริการดีมาก', 'คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก', 'ขนมตุ๊บตั๊บแพคมาดีค่ะ', 'เห็ดหอมสภาพดีค่ะ', 'ดอกไม่ใหญ่มากขนาดกลางๆ', 'สินค้าสภาพดี', 'สมราคา', 'คุ้มค่าไม่ไก่กาค่ะ', 'กลิ่นชาหอมมากกชาหอมมากค่ะ', 'สินค้าดีนะคะ', 'เข้ากับสีผิวดีสินค้าคุณภาพดีมาก', 'ผ้าหนามาก', 'ดีมาก', 'ได้รับของไวมากค่ะ', 'ไม่อร่อย', 'สั่งอย่างหนึ่งได้อย่างหนึ่ง', 'ไม่คุ้มกับความรู้สึกเมื่อเจอ', 'ถุงเท้าแข็งมากใส่ไม่สบายเลย', 'ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย', 'การให้บริการจากร้านค้าแย่มาก', 'คุณภาพของสินค้าแย่มาก', 'คุณภาพของสินค้าบางเกิน', 'คุณภาพของสินค้าแย่มาก', 'ความคุ้มค่าแย่มาก', 'ส่งช้า', 'ส่งของไม่ครบ', 'คงไม่อุดหนุนละค่ะ', 'คนแบบนี้ไม่ไหวจริงๆ', 'ซื้อร้านอื่นเลยคะ', 'เลยทิ้งทั้งหมดที่ซื้อ', 'เป้าขาด']
# ...

# %%
from pythainlp import sent_tokenize, word_tokenize

text = """
ชาหอมอร่อยดี อร่อยมากจ้า ความรวดเร็วในการจัดส่งดีมาก 
แพคสินค้าดี สินค้าคุณภาพสมราคา แม่ค้าน่ารักมาก ให้บริการดีมาก 
คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก
ขนมตุ๊บตั๊บแพคมาดีค่ะ เห็ดหอมสภาพดีค่ะ  
ดอกไม่ใหญ่มากขนาดกลางๆ 
สินค้าสภาพดี สมราคา 
คุ้มค่าไม่ไก่กาค่ะ กลิ่นชาหอมมากกชาหอมมากค่ะ สินค้าดีนะคะ 
เข้ากับสีผิวดีสินค้าคุณภาพดีมาก ผ้าหนามาก ดีมาก ได้รับของไวมากค่ะ ไม่อร่อย  
สั่งอย่างหนึ่งได้อย่างหนึ่ง ไม่คุ้มกับความรู้สึกเมื่อเจอ  
ถุงเท้าแข็งมากใส่ไม่สบายเลย ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย 
การให้บริการจากร้านค้าแย่มาก คุณภาพของสินค้าแย่มาก คุณภาพของสินค้าบางเกิน 
คุณภาพของสินค้าแย่มาก ความคุ้มค่าแย่มาก ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ 
คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ เลยทิ้งทั้งหมดที่ซื้อ เป้าขาด"""

print("sent_tokenize:", sent_tokenize(text))
print("word_tokenize:", word_tokenize(text))
print("word_tokenize, without whitespace:", word_tokenize(text, keep_whitespace=False))
# Out:
# sent_tokenize: ['ชาหอมอร่อยดี', 'อร่อยมากจ้า', 'ความรวดเร็วในการจัดส่งดีมาก', 'แพคสินค้าดี', 'สินค้าคุณภาพสมราคา', 'แม่ค้าน่ารักมาก', 'ให้บริการดีมาก', 'คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก', 'ขนมตุ๊บตั๊บแพคมาดีค่ะ', 'เห็ดหอมสภาพดีค่ะ', 'ดอกไม่ใหญ่มากขนาดกลางๆ', 'สินค้าสภาพดี', 'สมราคา', 'คุ้มค่าไม่ไก่กาค่ะ', 'กลิ่นชาหอมมากกชาหอมมากค่ะ', 'สินค้าดีนะคะ', 'เข้ากับสีผิวดีสินค้าคุณภาพดีมาก', 'ผ้าหนามาก', 'ดีมาก', 'ได้รับของไวมากค่ะ', 'ไม่อร่อย', 'สั่งอย่างหนึ่งได้อย่างหนึ่ง', 'ไม่คุ้มกับความรู้สึกเมื่อเจอ', 'ถุงเท้าแข็งมากใส่ไม่สบายเลย', 'ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย', 'การให้บริการจากร้านค้าแย่มาก', 'คุณภาพของสินค้าแย่มาก', 'คุณภาพของสินค้าบางเกิน', 'คุณภาพของสินค้าแย่มาก', 'ความคุ้มค่าแย่มาก', 'ส่งช้า', 'ส่งของไม่ครบ', 'คงไม่อุดหนุนละค่ะ', 'คนแบบนี้ไม่ไหวจริงๆ', 'ซื้อร้านอื่นเลยคะ', 'เลยทิ้งทั้งหมดที่ซื้อ', 'เป้าขาด']
# ...

# %%
from pythainlp import word_tokenize, Tokenizer

text = """
ชาหอมอร่อยดี อร่อยมากจ้า ความรวดเร็วในการจัดส่งดีมาก 
แพคสินค้าดี สินค้าคุณภาพสมราคา แม่ค้าน่ารักมาก ให้บริการดีมาก 
คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก
ขนมตุ๊บตั๊บแพคมาดีค่ะ เห็ดหอมสภาพดีค่ะ  
ดอกไม่ใหญ่มากขนาดกลางๆ 
สินค้าสภาพดี สมราคา 
คุ้มค่าไม่ไก่กาค่ะ กลิ่นชาหอมมากกชาหอมมากค่ะ สินค้าดีนะคะ 
เข้ากับสีผิวดีสินค้าคุณภาพดีมาก ผ้าหนามาก ดีมาก ได้รับของไวมากค่ะ ไม่อร่อย  
สั่งอย่างหนึ่งได้อย่างหนึ่ง ไม่คุ้มกับความรู้สึกเมื่อเจอ  
ถุงเท้าแข็งมากใส่ไม่สบายเลย ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย 
การให้บริการจากร้านค้าแย่มาก คุณภาพของสินค้าแย่มาก คุณภาพของสินค้าบางเกิน 
คุณภาพของสินค้าแย่มาก ความคุ้มค่าแย่มาก ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ 
คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ เลยทิ้งทั้งหมดที่ซื้อ เป้าขาด"""

print("newmm:", word_tokenize(text))  # default engine is "newmm"
print("longest:", word_tokenize(text, engine="longest"))

words = ["กฎ", "งาน"]
custom_tokenizer = Tokenizer(words)
print("custom:", custom_tokenizer.word_tokenize(text))
# Out:
# newmm: ['\n', 'ชา', 'หอม', 'อร่อย', 'ดี', ' ', 'อร่อย', 'มาก', 'จ้า', ' ', 'ความ', 'รวดเร็ว', 'ใน', 'การจัดส่ง', 'ดีมาก', ' ', '\n', 'แพ', 'ค', 'สินค้า', 'ดี', ' ', 'สินค้า', 'คุณภาพ', 'สมราคา', ' ', 'แม่ค้า', 'น่ารัก', 'มาก', ' ', 'ให้บริการ', 'ดีมาก', ' ', '\n', 'คุ้ม', 'มมมมมมมมมมมมมมมมมม', 'ค่า', 'มา', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', '\n', 'ขนม', 'ตุ๊', 'บตั๊บ', 'แพ', 'ค', 'มา', 'ดี', 'ค่ะ', ' ', 'เห็ด', 'หอม', 'สภาพ', 'ดี', 'ค่ะ', '  ', '\n', 'ดอก', 'ไม่', 'ใหญ่', 'มาก', 'ขนาด', 'กลางๆ', ' ', '\n', 'สินค้า', 'สภาพ', 'ดี', ' ', 'สมราคา', ' ', '\n', 'คุ้มค่า', 'ไม่', 'ไก่', 'กา', 'ค่ะ', ' ', 'กลิ่น', 'ชา', 'หอม', 'มา', 'กก', 'ชา', 'หอ', 'มมาก', 'ค่ะ', ' ', 'สินค้า', 'ดี', 'นะคะ', ' ', '\n', 'เข้ากับ', 'สีผิว', 'ดี', 'สินค้า', 'คุณภาพ', 'ดีมาก', ' ', 'ผ้า', 'หนา', 'มาก', ' ', 'ดีมาก', ' ', 'ได้รับ', 'ของ', 'ไว', 'มาก', 'ค่ะ', ' ', 'ไม่อร่อย', '  ', '\n', 'สั่ง', 'อย่างหนึ่ง', 'ได้', 'อย่างหนึ่ง', ' ', 'ไม่', 'คุ้ม', 'กับ', 'ความรู้สึก', 'เมื่อ', 'เจอ', '  ', '
# ...

# %%
from pythainlp import word_tokenize, Tokenizer

text = """
ชาหอมอร่อยดี อร่อยมากจ้า ความรวดเร็วในการจัดส่งดีมาก 
แพคสินค้าดี สินค้าคุณภาพสมราคา แม่ค้าน่ารักมาก ให้บริการดีมาก 
คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก
ขนมตุ๊บตั๊บแพคมาดีค่ะ เห็ดหอมสภาพดีค่ะ  
ดอกไม่ใหญ่มากขนาดกลางๆ 
สินค้าสภาพดี สมราคา 
คุ้มค่าไม่ไก่กาค่ะ กลิ่นชาหอมมากกชาหอมมากค่ะ สินค้าดีนะคะ 
เข้ากับสีผิวดีสินค้าคุณภาพดีมาก ผ้าหนามาก ดีมาก ได้รับของไวมากค่ะ ไม่อร่อย  
สั่งอย่างหนึ่งได้อย่างหนึ่ง ไม่คุ้มกับความรู้สึกเมื่อเจอ  
ถุงเท้าแข็งมากใส่ไม่สบายเลย ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย 
การให้บริการจากร้านค้าแย่มาก คุณภาพของสินค้าแย่มาก คุณภาพของสินค้าบางเกิน 
คุณภาพของสินค้าแย่มาก ความคุ้มค่าแย่มาก ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ 
คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ เลยทิ้งทั้งหมดที่ซื้อ เป้าขาด"""

print("newmm:", word_tokenize(text))  # default engine is "newmm"
print("longest:", word_tokenize(text, engine="longest"))

words = ["กฎ", "งาน"]
custom_tokenizer = Tokenizer(words)
print("custom:", custom_tokenizer.word_tokenize(text))
# Out:
# newmm: ['\n', 'ชา', 'หอม', 'อร่อย', 'ดี', ' ', 'อร่อย', 'มาก', 'จ้า', ' ', 'ความ', 'รวดเร็ว', 'ใน', 'การจัดส่ง', 'ดีมาก', ' ', '\n', 'แพ', 'ค', 'สินค้า', 'ดี', ' ', 'สินค้า', 'คุณภาพ', 'สมราคา', ' ', 'แม่ค้า', 'น่ารัก', 'มาก', ' ', 'ให้บริการ', 'ดีมาก', ' ', '\n', 'คุ้ม', 'มมมมมมมมมมมมมมมมมม', 'ค่า', 'มา', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', '\n', 'ขนม', 'ตุ๊', 'บตั๊บ', 'แพ', 'ค', 'มา', 'ดี', 'ค่ะ', ' ', 'เห็ด', 'หอม', 'สภาพ', 'ดี', 'ค่ะ', '  ', '\n', 'ดอก', 'ไม่', 'ใหญ่', 'มาก', 'ขนาด', 'กลางๆ', ' ', '\n', 'สินค้า', 'สภาพ', 'ดี', ' ', 'สมราคา', ' ', '\n', 'คุ้มค่า', 'ไม่', 'ไก่', 'กา', 'ค่ะ', ' ', 'กลิ่น', 'ชา', 'หอม', 'มา', 'กก', 'ชา', 'หอ', 'มมาก', 'ค่ะ', ' ', 'สินค้า', 'ดี', 'นะคะ', ' ', '\n', 'เข้ากับ', 'สีผิว', 'ดี', 'สินค้า', 'คุณภาพ', 'ดีมาก', ' ', 'ผ้า', 'หนา', 'มาก', ' ', 'ดีมาก', ' ', 'ได้รับ', 'ของ', 'ไว', 'มาก', 'ค่ะ', ' ', 'ไม่อร่อย', '  ', '\n', 'สั่ง', 'อย่างหนึ่ง', 'ได้', 'อย่างหนึ่ง', ' ', 'ไม่', 'คุ้ม', 'กับ', 'ความรู้สึก', 'เมื่อ', 'เจอ', '  ', '
# ...

# %%
from pythainlp.corpus.common import thai_words
from pythainlp import word_tokenize, Tokenizer

text = """
ชาหอมอร่อยดี อร่อยมากจ้า ความรวดเร็วในการจัดส่งดีมาก 
แพคสินค้าดี สินค้าคุณภาพสมราคา แม่ค้าน่ารักมาก ให้บริการดีมาก 
คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก
ขนมตุ๊บตั๊บแพคมาดีค่ะ เห็ดหอมสภาพดีค่ะ  
ดอกไม่ใหญ่มากขนาดกลางๆ 
สินค้าสภาพดี สมราคา 
คุ้มค่าไม่ไก่กาค่ะ กลิ่นชาหอมมากกชาหอมมากค่ะ สินค้าดีนะคะ 
เข้ากับสีผิวดีสินค้าคุณภาพดีมาก ผ้าหนามาก ดีมาก ได้รับของไวมากค่ะ ไม่อร่อย  
สั่งอย่างหนึ่งได้อย่างหนึ่ง ไม่คุ้มกับความรู้สึกเมื่อเจอ  
ถุงเท้าแข็งมากใส่ไม่สบายเลย ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย 
การให้บริการจากร้านค้าแย่มาก คุณภาพของสินค้าแย่มาก คุณภาพของสินค้าบางเกิน 
คุณภาพของสินค้าแย่มาก ความคุ้มค่าแย่มาก ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ 
คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ เลยทิ้งทั้งหมดที่ซื้อ เป้าขาด"""

print("newmm:", word_tokenize(text))

words = set(thai_words())  # thai_words() returns frozenset
words.add("อสิมอฟ")
custom_tokenizer = Tokenizer(words)
print("custom:", custom_tokenizer.word_tokenize(text))
# Out:
# newmm: ['\n', 'ชา', 'หอม', 'อร่อย', 'ดี', ' ', 'อร่อย', 'มาก', 'จ้า', ' ', 'ความ', 'รวดเร็ว', 'ใน', 'การจัดส่ง', 'ดีมาก', ' ', '\n', 'แพ', 'ค', 'สินค้า', 'ดี', ' ', 'สินค้า', 'คุณภาพ', 'สมราคา', ' ', 'แม่ค้า', 'น่ารัก', 'มาก', ' ', 'ให้บริการ', 'ดีมาก', ' ', '\n', 'คุ้ม', 'มมมมมมมมมมมมมมมมมม', 'ค่า', 'มา', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', 'กก', '\n', 'ขนม', 'ตุ๊', 'บตั๊บ', 'แพ', 'ค', 'มา', 'ดี', 'ค่ะ', ' ', 'เห็ด', 'หอม', 'สภาพ', 'ดี', 'ค่ะ', '  ', '\n', 'ดอก', 'ไม่', 'ใหญ่', 'มาก', 'ขนาด', 'กลางๆ', ' ', '\n', 'สินค้า', 'สภาพ', 'ดี', ' ', 'สมราคา', ' ', '\n', 'คุ้มค่า', 'ไม่', 'ไก่', 'กา', 'ค่ะ', ' ', 'กลิ่น', 'ชา', 'หอม', 'มา', 'กก', 'ชา', 'หอ', 'มมาก', 'ค่ะ', ' ', 'สินค้า', 'ดี', 'นะคะ', ' ', '\n', 'เข้ากับ', 'สีผิว', 'ดี', 'สินค้า', 'คุณภาพ', 'ดีมาก', ' ', 'ผ้า', 'หนา', 'มาก', ' ', 'ดีมาก', ' ', 'ได้รับ', 'ของ', 'ไว', 'มาก', 'ค่ะ', ' ', 'ไม่อร่อย', '  ', '\n', 'สั่ง', 'อย่างหนึ่ง', 'ได้', 'อย่างหนึ่ง', ' ', 'ไม่', 'คุ้ม', 'กับ', 'ความรู้สึก', 'เมื่อ', 'เจอ', '  ', '
# ...

# %%
speedtest_text = """
ชาหอมอร่อยดี อร่อยมากจ้า ความรวดเร็วในการจัดส่งดีมาก 
แพคสินค้าดี สินค้าคุณภาพสมราคา แม่ค้าน่ารักมาก ให้บริการดีมาก 
คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก
ขนมตุ๊บตั๊บแพคมาดีค่ะ เห็ดหอมสภาพดีค่ะ  
ดอกไม่ใหญ่มากขนาดกลางๆ 
สินค้าสภาพดี สมราคา 
คุ้มค่าไม่ไก่กาค่ะ กลิ่นชาหอมมากกชาหอมมากค่ะ สินค้าดีนะคะ 
เข้ากับสีผิวดีสินค้าคุณภาพดีมาก ผ้าหนามาก ดีมาก ได้รับของไวมากค่ะ ไม่อร่อย  
สั่งอย่างหนึ่งได้อย่างหนึ่ง ไม่คุ้มกับความรู้สึกเมื่อเจอ  
ถุงเท้าแข็งมากใส่ไม่สบายเลย ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย 
การให้บริการจากร้านค้าแย่มาก คุณภาพของสินค้าแย่มาก คุณภาพของสินค้าบางเกิน 
คุณภาพของสินค้าแย่มาก ความคุ้มค่าแย่มาก ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ 
คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ เลยทิ้งทั้งหมดที่ซื้อ เป้าขาด"""

# %%
# Speed test: Calling "longest" engine through word_tokenize wrapper
# %time tokens = word_tokenize(speedtest_text, engine="longest")
# Out:
# CPU times: user 235 ms, sys: 1.18 ms, total: 236 ms
# Wall time: 235 ms

# %%
# Speed test: Calling "newmm" engine through word_tokenize wrapper
# %time tokens = word_tokenize(speedtest_text, engine="newmm")
# Out:
# CPU times: user 3.15 ms, sys: 14 µs, total: 3.16 ms
# Wall time: 3.17 ms

# %%
# Speed test: Directly call "newmm" engine from pythainlp.tokenize.newmm
# %time tokens = pythainlp.tokenize.newmm.segment(speedtest_text)
# Out:
# CPU times: user 3.16 ms, sys: 0 ns, total: 3.16 ms
# Wall time: 3.16 ms

# %%
# Get all possible segmentations
from pythainlp.tokenize.multi_cut import find_all_segment, mmcut, segment

find_all_segment("คนแบบนี้ไม่ไหวจริงๆ")
# Out:
# ['คน|แบบ|นี้|ไม่|ไหว|จริงๆ|',
#  'คน|แบบนี้|ไม่|ไหว|จริงๆ|',
#  'คน|แบบ|นี้|ไม่ไหว|จริงๆ|',
#  'คน|แบบนี้|ไม่ไหว|จริงๆ|']

# %% [markdown]
# # POS Part-of-Speech Tagging

# %%
from pythainlp.tag import pos_tag, pos_tag_sents

pos_tag(["ชาหอมอร่อยดี" ,
"อร่อยมากจ้า" ,
"ความรวดเร็วในการจัดส่งดีมาก",
"แพคสินค้าดี", 
"สินค้าคุณภาพสมราคา", 
"แม่ค้าน่ารักมาก ให้บริการดีมาก", 
"คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก",
"ขนมตุ๊บตั๊บแพคมาดีค่ะ",
"เห็ดหอมสภาพดีค่ะ",  
"กลิ่นชาหอมมากกชาหอมมากค่ะ", 
"ไม่อร่อย",  
"สั่งอย่างหนึ่งได้อย่างหนึ่ง",
"ไม่คุ้มกับความรู้สึกเมื่อเจอ",  
"ถุงเท้าแข็งมากใส่ไม่สบายเลย",
"ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย",
"การให้บริการจากร้านค้าแย่มาก",
"คุณภาพของสินค้าแย่มาก",
"คุณภาพของสินค้าบางเกิน",
"คุณภาพของสินค้าแย่มาก",
"ความคุ้มค่าแย่มาก", 
"ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ", 
"คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ", 
"ทิ้งทั้งหมดที่ซื้อ เป้าขาด"])
# Out:
# [('ชาหอมอร่อยดี', 'NCMN'),
#  ('อร่อยมากจ้า', 'NCMN'),
#  ('ความรวดเร็วในการจัดส่งดีมาก', 'VATT'),
#  ('แพคสินค้าดี', 'NCMN'),
#  ('สินค้าคุณภาพสมราคา', 'NCMN'),
#  ('แม่ค้าน่ารักมาก ให้บริการดีมาก', 'VATT'),
#  ('คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก', 'NCMN'),
#  ('ขนมตุ๊บตั๊บแพคมาดีค่ะ', 'NCMN'),
#  ('เห็ดหอมสภาพดีค่ะ', 'NCMN'),
#  ('กลิ่นชาหอมมากกชาหอมมากค่ะ', 'NCMN'),
#  ('ไม่อร่อย', 'NCMN'),
#  ('สั่งอย่างหนึ่งได้อย่างหนึ่ง', 'DCNM'),
#  ('ไม่คุ้มกับความรู้สึกเมื่อเจอ', 'NCMN'),
#  ('ถุงเท้าแข็งมากใส่ไม่สบายเลย', 'ADVN'),
#  ('ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย', 'ADVN'),
#  ('การให้บริการจากร้านค้าแย่มาก', 'ADVN'),
#  ('คุณภาพของสินค้าแย่มาก', 'ADVN'),
#  ('คุณภาพของสินค้าบางเกิน', 'ADVN'),
#  ('คุณภาพของสินค้าแย่มาก', 'ADVN'),
#  ('ความคุ้มค่าแย่มาก', 'ADVN'),
#  ('ส่งช้า ส่งของไม่ครบ คงไม่อุดหนุนละค่ะ', 'NCMN'),
#  ('คนแบบนี้ไม่ไหวจริงๆ ซื้อร้านอื่นเลยคะ', 'NCMN'),
#  ('ทิ้งทั้งหมดที่ซื้อ เป้าขาด', 'NCMN')]

# %%
from pythainlp.tag import pos_tag, pos_tag_sents

pos_tag(["ชา","หอม","อร่อยดี" ,
"อร่อยมากจ้า" ,
"ความรวดเร็วในการจัดส่ง","ดีมาก",
"แพคสินค้าดี", 
"สินค้าคุณภาพสมราคา", 
"แม่ค้าน่ารักมาก", "ให้บริการดีมาก", 
"คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก",
"ขนมตุ๊บตั๊บ","แพค","มาดีค่ะ",
"เห็ดหอมสภาพดีค่ะ",  
"กลิ่นชา","หอมมากก""ชาหอมมากค่ะ", 
"ไม่อร่อย",  
"สั่งอย่างหนึ่งได้อย่างหนึ่ง",
"ไม่คุ้มกับความรู้สึกเมื่อเจอ",  
"ถุงเท้า","แข็งมาก","ใส่ไม่สบายเลย",
"ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย",
"การให้บริการ","จากร้านค้า","แย่มาก",
"คุณภาพของสินค้า","แย่มาก",
"คุณภาพของสินค้า","บางเกิน",
"ความคุ้มค่า","แย่มาก", 
"ส่งช้า","ส่งของไม่ครบ","คงไม่อุดหนุนละค่ะ", 
"คนแบบนี้ไม่ไหวจริงๆ"," ซื้อร้านอื่นเลยคะ", 
"ทิ้งทั้งหมดที่ซื้อ","เป้าขาด"])
# Out:
# [('ชา', 'NCMN'),
#  ('หอม', 'NCMN'),
#  ('อร่อยดี', 'ADVP'),
#  ('อร่อยมากจ้า', 'NCMN'),
#  ('ความรวดเร็วในการจัดส่ง', 'NCMN'),
#  ('ดีมาก', 'VATT'),
#  ('แพคสินค้าดี', 'NCMN'),
#  ('สินค้าคุณภาพสมราคา', 'NCMN'),
#  ('แม่ค้าน่ารักมาก', 'VATT'),
#  ('ให้บริการดีมาก', 'ADVN'),
#  ('คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก', 'NCMN'),
#  ('ขนมตุ๊บตั๊บ', 'NCMN'),
#  ('แพค', 'NCMN'),
#  ('มาดีค่ะ', 'NCMN'),
#  ('เห็ดหอมสภาพดีค่ะ', 'NCMN'),
#  ('กลิ่นชา', 'NCMN'),
#  ('หอมมากกชาหอมมากค่ะ', 'NCMN'),
#  ('ไม่อร่อย', 'NCMN'),
#  ('สั่งอย่างหนึ่งได้อย่างหนึ่ง', 'DCNM'),
#  ('ไม่คุ้มกับความรู้สึกเมื่อเจอ', 'NCMN'),
#  ('ถุงเท้า', 'NCMN'),
#  ('แข็งมาก', 'VATT'),
#  ('ใส่ไม่สบายเลย', 'ADVN'),
#  ('ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย', 'NCMN'),
#  ('การให้บริการ', 'NCMN'),
#  ('จากร้านค้า', 'NCMN'),
#  ('แย่มาก', 'VATT'),
#  ('คุณภาพของสินค้า', 'NCMN'),
#  ('แย่มาก', 'ADVP'),
#  ('คุณภาพของสินค้า', 'NCMN'),
#  ('บางเกิน', 'VACT'),
#  ('ความคุ้มค่า', 'NCMN'),
# ...

# %%
from pythainlp.sentiment import sentiment
text = ["ชา","หอม","อร่อยดี" ,
"อร่อยมากจ้า" ,
"ความรวดเร็วในการจัดส่ง","ดีมาก",
"แพคสินค้าดี", 
"สินค้าคุณภาพสมราคา", 
"แม่ค้าน่ารักมาก", "ให้บริการดีมาก", 
"คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก",
"ขนมตุ๊บตั๊บ","แพค","มาดีค่ะ",
"เห็ดหอมสภาพดีค่ะ",  
"กลิ่นชา","หอมมากก""ชาหอมมากค่ะ", 
"ไม่อร่อย",  
"สั่งอย่างหนึ่งได้อย่างหนึ่ง",
"ไม่คุ้มกับความรู้สึกเมื่อเจอ",  
"ถุงเท้า","แข็งมาก","ใส่ไม่สบายเลย",
"ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย",
"การให้บริการ","จากร้านค้า","แย่มาก",
"คุณภาพของสินค้า","แย่มาก",
"คุณภาพของสินค้า","บางเกิน",
"ความคุ้มค่า","แย่มาก", 
"ส่งช้า","ส่งของไม่ครบ","คงไม่อุดหนุนละค่ะ", 
"คนแบบนี้ไม่ไหวจริงๆ"," ซื้อร้านอื่นเลยคะ", 
"ทิ้งทั้งหมดที่ซื้อ","เป้าขาด"]
sentiment(text)
# Out:
# 'neg'

# %%
from pythainlp.sentiment import sentiment
text = "ชาหอมอร่อยดี อร่อยมากจ้า ความรวดเร็วในการจัดส่งดีมาก แพคสินค้าดี สินค้าคุณภาพสมราคา แม่ค้าน่ารักมาก ให้บริการดีมาก"
sentiment(text)
# Out:
# 'pos'

# %%
from pythainlp.sentiment import sentiment
text = "ชาหอมมากค่ะ"
sentiment(text)
#ไม่ตรง
# Out:
# 'neg'

# %%
from pythainlp.sentiment import sentiment
text = "คุ้มมมมมมมมมมมมมมมมมมมค่ามากกกกกกกกกกกกกกกกกก"
sentiment(text)
#ไม่ตรง
# Out:
# 'neg'

# %%
from pythainlp.sentiment import sentiment
text = ["แย่มาก ","ดีมาก"]
sentiment(text)
# Out:
# 'neg'

# %%
from pythainlp.sentiment import sentiment
text = ["ทิ้งทั้งหมดที่ซื้อ"]
sentiment(text)
# Out:
# 'neg'

# %%
from pythainlp.sentiment import sentiment
text = ["ถ้าคุณยอมรับความคิดเห็นไม่ได้ยังสมควรขายสินค้าอยู่มั้ย"]
sentiment(text)
# Out:
# 'neg'
